# %%
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
fandango = pd.read_csv(r"C:\Users\Ruchi Garg\Downloads\fandango_scrape.csv")

# %%
fandango
# Out:
#                                      FILM  STARS  RATING  VOTES
# 0             Fifty Shades of Grey (2015)    4.0     3.9  34846
# 1                   Jurassic World (2015)    4.5     4.5  34390
# 2                  American Sniper (2015)    5.0     4.8  34085
# 3                        Furious 7 (2015)    5.0     4.8  33538
# 4                       Inside Out (2015)    4.5     4.5  15749
# ..                                    ...    ...     ...    ...
# 505                      Valiyavan (2015)    0.0     0.0      0
# 506            WWE SummerSlam 2015 (2015)    0.0     0.0      0
# 507       Yagavarayinum Naa Kaakka (2015)    0.0     0.0      0
# 508  Yesterday, Today and Tomorrow (1964)    0.0     0.0      0
# 509                            Zarafa (1)    0.0     0.0      0
#
# [510 rows x 4 columns]

# %%
fandango.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 510 entries, 0 to 509
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   FILM    510 non-null    object
#  1   STARS   510 non-null    float64
#  2   RATING  510 non-null    float64
#  3   VOTES   510 non-null    int64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 16.1+ KB

# %%
fandango.describe()
# Out:
#             STARS      RATING         VOTES
# count  510.000000  510.000000    510.000000
# mean     3.532353    3.351765   1134.364706
# std      1.585616    1.512628   3809.952176
# min      0.000000    0.000000      0.000000
# 25%      3.500000    3.025000      2.000000
# 50%      4.000000    3.800000     17.500000
# 75%      4.500000    4.300000    183.500000
# max      5.000000    5.000000  34846.000000

# %%
sns.scatterplot(data=fandango,x='RATING',y='VOTES');

# %%
fandango.corr()
# Out:
# C:\Users\Ruchi Garg\AppData\Local\Temp\ipykernel_25188\1316820973.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   fandango.corr()
#            STARS    RATING     VOTES
# STARS   1.000000  0.994870  0.165774
# RATING  0.994870  1.000000  0.165147
# VOTES   0.165774  0.165147  1.000000

# %%
fandango['FILM'].apply(lambda x:x.split('(')[-1])
# Out:
# 0      2015)
# 1      2015)
# 2      2015)
# 3      2015)
# 4      2015)
#        ...
# 505    2015)
# 506    2015)
# 507    2015)
# 508    1964)
# 509       1)
# Name: FILM, Length: 510, dtype: object

# %%
fandango['FILM'].apply(lambda x:x.split('(')[-1]).apply(lambda x:x.split(')')[0])
# Out:
# 0      2015
# 1      2015
# 2      2015
# 3      2015
# 4      2015
#        ...
# 505    2015
# 506    2015
# 507    2015
# 508    1964
# 509       1
# Name: FILM, Length: 510, dtype: object

# %%
fandango['Year'] = fandango['FILM'].apply(lambda x:x.split('(')[-1]).apply(lambda x:x.split(')')[0])

# %%
fandango
# Out:
#                                      FILM  STARS  RATING  VOTES  Year
# 0             Fifty Shades of Grey (2015)    4.0     3.9  34846  2015
# 1                   Jurassic World (2015)    4.5     4.5  34390  2015
# 2                  American Sniper (2015)    5.0     4.8  34085  2015
# 3                        Furious 7 (2015)    5.0     4.8  33538  2015
# 4                       Inside Out (2015)    4.5     4.5  15749  2015
# ..                                    ...    ...     ...    ...   ...
# 505                      Valiyavan (2015)    0.0     0.0      0  2015
# 506            WWE SummerSlam 2015 (2015)    0.0     0.0      0  2015
# 507       Yagavarayinum Naa Kaakka (2015)    0.0     0.0      0  2015
# 508  Yesterday, Today and Tomorrow (1964)    0.0     0.0      0  1964
# 509                            Zarafa (1)    0.0     0.0      0     1
#
# [510 rows x 5 columns]

# %%
sns.countplot(data= fandango,x='Year')
# Out:
# <Axes: xlabel='Year', ylabel='count'>

# %%
# Top 10 movies with higest number of votes
fandango.nlargest(10,'VOTES')
# Out:
#                                                FILM  STARS  RATING  VOTES  \
# 0                       Fifty Shades of Grey (2015)    4.0     3.9  34846
# 1                             Jurassic World (2015)    4.5     4.5  34390
# 2                            American Sniper (2015)    5.0     4.8  34085
# 3                                  Furious 7 (2015)    5.0     4.8  33538
# 4                                 Inside Out (2015)    4.5     4.5  15749
# 5  The Hobbit: The Battle of the Five Armies (2014)    4.5     4.3  15337
# 6               Kingsman: The Secret Service (2015)    4.5     4.2  15205
# 7                                    Minions (2015)    4.0     4.0  14998
# 8                    Avengers: Age of Ultron (2015)    5.0     4.5  14846
# 9                             Into the Woods (2014)    3.5     3.4  13055
#
#    Year
# 0  2015
# 1  2015
# 2  2015
# 3  2015
# 4  2015
# 5  2014
# 6  2015
# 7  2015
# 8  2015
# 9  2014

# %%
fandango.nlargest(10,'VOTES')[['FILM','VOTES']]
# Out:
#                                                FILM  VOTES
# 0                       Fifty Shades of Grey (2015)  34846
# 1                             Jurassic World (2015)  34390
# 2                            American Sniper (2015)  34085
# 3                                  Furious 7 (2015)  33538
# 4                                 Inside Out (2015)  15749
# 5  The Hobbit: The Battle of the Five Armies (2014)  15337
# 6               Kingsman: The Secret Service (2015)  15205
# 7                                    Minions (2015)  14998
# 8                    Avengers: Age of Ultron (2015)  14846
# 9                             Into the Woods (2014)  13055

# %%
(fandango['VOTES']== 0).sum()
# Out:
# 73

# %%
# movies with 0 votes
fandango['VOTES']== 0
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 505     True
# 506     True
# 507     True
# 508     True
# 509     True
# Name: VOTES, Length: 510, dtype: bool

# %%
fandango_new = fandango[fandango['VOTES'] != 0]
len(fandango_new)
# Out:
# 437

# %%
437+73
# Out:
# 510

# %%
fandango.columns
# Out:
# Index(['FILM', 'STARS', 'RATING', 'VOTES', 'Year'], dtype='object')

# %%
sns.kdeplot(data=fandango_new,x='RATING')
sns.kdeplot(data=fandango_new,x='STARS')
# Out:
# <Axes: xlabel='RATING', ylabel='Density'>

# %%
plt.figure(figsize=(10,4))
sns.kdeplot(data=fandango_new,x='RATING',fill= True)
sns.kdeplot(data=fandango_new,x='STARS',fill= True)
# Out:
# <Axes: xlabel='RATING', ylabel='Density'>

# %%
plt.figure(figsize=(10,4))
sns.kdeplot(data=fandango_new,x='RATING',fill= True)
sns.kdeplot(data=fandango_new,x='STARS',fill= True)
plt.title('RATING vs STARS')
# Out:
# Text(0.5, 1.0, 'RATING vs STARS')

# %%
 
plt.title('RATING vs STARS')
plt.legend(loc=(1.02,1.02))

# %%
fandango_new['diff_stars']=fandango_new['STARS']-fandango_new['RATING']
fandango_new
# Out:
# C:\Users\Ruchi Garg\AppData\Local\Temp\ipykernel_25188\2062791979.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fandango_new['diff_stars']=fandango_new['STARS']-fandango_new['RATING']
#                             FILM  STARS  RATING  VOTES  Year  diff_stars
# 0    Fifty Shades of Grey (2015)    4.0     3.9  34846  2015         0.1
# 1          Jurassic World (2015)    4.5     4.5  34390  2015         0.0
# 2         American Sniper (2015)    5.0     4.8  34085  2015         0.2
# 3               Furious 7 (2015)    5.0     4.8  33538  2015         0.2
# 4              Inside Out (2015)    4.5     4.5  15749  2015         0.0
# ..                           ...    ...     ...    ...   ...         ...
# 432       That Sugar Film (2015)    5.0     5.0      1  2015         0.0
# 433            The Intern (2015)    5.0     5.0      1  2015         0.0
# 434        The Park Bench (2015)    5.0     5.0      1  2015         0.0
# 435         The Wanted 18 (2015)    5.0     5.0      1  2015         0.0
# 436       Z For Zachariah (2015)    5.0     5.0      1  2015         0.0
#
# [437 rows x 6 columns]

# %%
sns.countplot(data=fandango_new,x='diff_stars')
# Out:
# <Axes: xlabel='diff_stars', ylabel='count'>

# %%
fandango_new[fandango_new['diff_stars']==1]
# Out:
#                  FILM  STARS  RATING  VOTES  Year  diff_stars
# 381  Turbo Kid (2015)    5.0     4.0      2  2015         1.0

# %%
 all_sites = pd.read_csv(r"C:\Users\Ruchi Garg\Downloads\fandango_score_comparison.csv")

# %%
all_sites
# Out:
#                                           FILM  RottenTomatoes  \
# 0               Avengers: Age of Ultron (2015)              74
# 1                            Cinderella (2015)              85
# 2                               Ant-Man (2015)              80
# 3                       Do You Believe? (2015)              18
# 4                Hot Tub Time Machine 2 (2015)              14
# ..                                         ...             ...
# 141                          Mr. Holmes (2015)              87
# 142                                 '71 (2015)              97
# 143                 Two Days, One Night (2014)              97
# 144  Gett: The Trial of Viviane Amsalem (2015)             100
# 145         Kumiko, The Treasure Hunter (2015)              87
#
#      RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  Fandango_Stars  \
# 0                     86          66              7.1   7.8             5.0
# 1                     80          67              7.5   7.1             5.0
# 2                     90          64              8.1   7.8             5.0
# 3                     84          22              4.7   5.4             5.0
# 4                     28          29              3.4   5.1             3.5
# ..                   ...         ...              ...   ...             ...
# 141                   78          67              7.9   7.4             4.0
# 142                   82          83              7.5   7.2             3.5
# 143                   78          89              8.8   7.4             3.5
# 144                   81          90              7.3   7.8             3.5
# 145                   63          68              6.4   6.7             3.5
#
#      Fandango_Ratingvalue  RT_norm  RT_user_norm  ...  IMDB_norm  \
# 0                     4.5     3.70          4.30  ...       3.90
# 1                     4.5     4.25          4.00  ...       3.55
# 2                     4.5     4.00          4.50  ...       3.90
# 3                     4.5     0.90          4.20  ...       2.70
# 4                     3.0     0.70          1.40  ...       2.55
# ..                    ...      ...           ...  ...        ...
# 141                   4.0     4.35          3.90  ...       3.70
# 142                   3.5     4.85          4.10  ...       3.60
# 143                   3.5     4.85          3.90  ...       3.70
# 144                   3.5     5.00          4.05  ...       3.90
# 145                   3.5     4.35          3.15  ...       3.35
#
#      RT_norm_round  RT_user_norm_round  Metacritic_norm_round  \
# 0              3.5                 4.5                    3.5
# 1              4.5                 4.0                    3.5
# 2              4.0                 4.5                    3.0
# 3              1.0                 4.0                    1.0
# 4              0.5                 1.5                    1.5
# ..             ...                 ...                    ...
# 141            4.5                 4.0                    3.5
# 142            5.0                 4.0                    4.0
# 143            5.0                 4.0                    4.5
# 144            5.0                 4.0                    4.5
# 145            4.5                 3.0                    3.5
#
#      Metacritic_user_norm_round  IMDB_norm_round  Metacritic_user_vote_count  \
# 0                           3.5              4.0                        1330
# 1                           4.0              3.5                         249
# 2                           4.0              4.0                         627
# 3                           2.5              2.5                          31
# 4                           1.5              2.5                          88
# ..                          ...              ...                         ...
# 141                         4.0              3.5                          33
# 142                         4.0              3.5                          60
# 143                         4.5              3.5                         123
# 144                         3.5              4.0                          19
# 145                         3.0              3.5                          19
#
#      IMDB_user_vote_count  Fandango_votes  Fandango_Difference
# 0                  271107           14846                  0.5
# 1                   65709           12640                  0.5
# 2                  103660           12055                  0.5
# 3                    3136            1793                  0.5
# 4                   19560            1021                  0.5
# ..                    ...             ...                  ...
# 141                  7367            1348                  0.0
# 142                 24116             192                  0.0
# 143                 24345             118                  0.0
# 144                  1955              59                  0.0
# 145                  5289              41                  0.0
#
# [146 rows x 22 columns]

# %%
all_sites.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146 entries, 0 to 145
# Data columns (total 22 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   FILM                        146 non-null    object
#  1   RottenTomatoes              146 non-null    int64
#  2   RottenTomatoes_User         146 non-null    int64
#  3   Metacritic                  146 non-null    int64
#  4   Metacritic_User             146 non-null    float64
#  5   IMDB                        146 non-null    float64
#  6   Fandango_Stars              146 non-null    float64
#  7   Fandango_Ratingvalue        146 non-null    float64
#  8   RT_norm                     146 non-null    float64
#  9   RT_user_norm                146 non-null    float64
#  10  Metacritic_norm             146 non-null    float64
#  11  Metacritic_user_nom         146 non-null    float64
#  12  IMDB_norm                   146 non-null    float64
#  13  RT_norm_round               146 non-null    float64
#  14  RT_user_norm_round          146 non-null    float64
#  15  Metacritic_norm_round       146 non-null    float64
#  16  Metacritic_user_norm_round  146 non-null    float64
#  17  IMDB_norm_round             146 non-null    float64
#  18  Metacritic_user_vote_count  146 non-null    int64
#  19  IMDB_user_vote_count        146 non-null    int64
#  20  Fandango_votes              146 non-null    int64
#  21  Fandango_Difference         146 non-null    float64
# dtypes: float64(15), int64(6), object(1)
# memory usage: 25.2+ KB

# %%
all_sites.describe()
# Out:
#        RottenTomatoes  RottenTomatoes_User  Metacritic  Metacritic_User  \
# count      146.000000           146.000000  146.000000       146.000000
# mean        60.849315            63.876712   58.808219         6.519178
# std         30.168799            20.024430   19.517389         1.510712
# min          5.000000            20.000000   13.000000         2.400000
# 25%         31.250000            50.000000   43.500000         5.700000
# 50%         63.500000            66.500000   59.000000         6.850000
# 75%         89.000000            81.000000   75.000000         7.500000
# max        100.000000            94.000000   94.000000         9.600000
#
#              IMDB  Fandango_Stars  Fandango_Ratingvalue     RT_norm  \
# count  146.000000      146.000000            146.000000  146.000000
# mean     6.736986        4.089041              3.845205    3.042466
# std      0.958736        0.540386              0.502831    1.508440
# min      4.000000        3.000000              2.700000    0.250000
# 25%      6.300000        3.500000              3.500000    1.562500
# 50%      6.900000        4.000000              3.900000    3.175000
# 75%      7.400000        4.500000              4.200000    4.450000
# max      8.600000        5.000000              4.800000    5.000000
#
#        RT_user_norm  Metacritic_norm  ...   IMDB_norm  RT_norm_round  \
# count    146.000000       146.000000  ...  146.000000     146.000000
# mean       3.193836         2.940411  ...    3.368493       3.065068
# std        1.001222         0.975869  ...    0.479368       1.514600
# min        1.000000         0.650000  ...    2.000000       0.500000
# 25%        2.500000         2.175000  ...    3.150000       1.500000
# 50%        3.325000         2.950000  ...    3.450000       3.000000
# 75%        4.050000         3.750000  ...    3.700000       4.500000
# max        4.700000         4.700000  ...    4.300000       5.000000
#
#        RT_user_norm_round  Metacritic_norm_round  Metacritic_user_norm_round  \
# count          146.000000             146.000000                  146.000000
# mean             3.226027               2.972603                    3.270548
# std              1.007014               0.990961                    0.788116
# min              1.000000               0.500000                    1.000000
# 25%              2.500000               2.125000                    3.000000
# 50%              3.500000               3.000000                    3.500000
# 75%              4.000000               4.000000                    4.000000
# max              4.500000               4.500000                    5.000000
#
#        IMDB_norm_round  Metacritic_user_vote_count  IMDB_user_vote_count  \
# count       146.000000                  146.000000            146.000000
# mean          3.380137                  185.705479          42846.205479
# std           0.502767                  316.606515          67406.509171
# min           2.000000                    4.000000            243.000000
# 25%           3.000000                   33.250000           5627.000000
# 50%           3.500000                   72.500000          19103.000000
# 75%           3.500000                  168.500000          45185.750000
# max           4.500000                 2375.000000         334164.000000
#
#        Fandango_votes  Fandango_Difference
# count      146.000000           146.000000
# mean      3848.787671             0.243836
# std       6357.778617             0.152665
# min         35.000000             0.000000
# 25%        222.250000             0.100000
# 50%       1446.000000             0.200000
# 75%       4439.500000             0.400000
# max      34846.000000             0.500000
#
# [8 rows x 21 columns]

# %%
sns.scatterplot(data=all_sites,x='RottenTomatoes',y='RottenTomatoes_User')
# Out:
# <Axes: xlabel='RottenTomatoes', ylabel='RottenTomatoes_User'>

# %%
all_sites['RottenTomatoes_diff']= all_sites['RottenTomatoes']-all_sites['RottenTomatoes_User']
all_sites


#large +ve values means user
# Out:
#                                           FILM  RottenTomatoes  \
# 0               Avengers: Age of Ultron (2015)              74
# 1                            Cinderella (2015)              85
# 2                               Ant-Man (2015)              80
# 3                       Do You Believe? (2015)              18
# 4                Hot Tub Time Machine 2 (2015)              14
# ..                                         ...             ...
# 141                          Mr. Holmes (2015)              87
# 142                                 '71 (2015)              97
# 143                 Two Days, One Night (2014)              97
# 144  Gett: The Trial of Viviane Amsalem (2015)             100
# 145         Kumiko, The Treasure Hunter (2015)              87
#
#      RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  Fandango_Stars  \
# 0                     86          66              7.1   7.8             5.0
# 1                     80          67              7.5   7.1             5.0
# 2                     90          64              8.1   7.8             5.0
# 3                     84          22              4.7   5.4             5.0
# 4                     28          29              3.4   5.1             3.5
# ..                   ...         ...              ...   ...             ...
# 141                   78          67              7.9   7.4             4.0
# 142                   82          83              7.5   7.2             3.5
# 143                   78          89              8.8   7.4             3.5
# 144                   81          90              7.3   7.8             3.5
# 145                   63          68              6.4   6.7             3.5
#
#      Fandango_Ratingvalue  RT_norm  RT_user_norm  ...  RT_norm_round  \
# 0                     4.5     3.70          4.30  ...            3.5
# 1                     4.5     4.25          4.00  ...            4.5
# 2                     4.5     4.00          4.50  ...            4.0
# 3                     4.5     0.90          4.20  ...            1.0
# 4                     3.0     0.70          1.40  ...            0.5
# ..                    ...      ...           ...  ...            ...
# 141                   4.0     4.35          3.90  ...            4.5
# 142                   3.5     4.85          4.10  ...            5.0
# 143                   3.5     4.85          3.90  ...            5.0
# 144                   3.5     5.00          4.05  ...            5.0
# 145                   3.5     4.35          3.15  ...            4.5
#
#      RT_user_norm_round  Metacritic_norm_round  Metacritic_user_norm_round  \
# 0                   4.5                    3.5                         3.5
# 1                   4.0                    3.5                         4.0
# 2                   4.5                    3.0                         4.0
# 3                   4.0                    1.0                         2.5
# 4                   1.5                    1.5                         1.5
# ..                  ...                    ...                         ...
# 141                 4.0                    3.5                         4.0
# 142                 4.0                    4.0                         4.0
# 143                 4.0                    4.5                         4.5
# 144                 4.0                    4.5                         3.5
# 145                 3.0                    3.5                         3.0
#
#      IMDB_norm_round  Metacritic_user_vote_count  IMDB_user_vote_count  \
# 0                4.0                        1330                271107
# 1                3.5                         249                 65709
# 2                4.0                         627                103660
# 3                2.5                          31                  3136
# 4                2.5                          88                 19560
# ..               ...                         ...                   ...
# 141              3.5                          33                  7367
# 142              3.5                          60                 24116
# 143              3.5                         123                 24345
# 144              4.0                          19                  1955
# 145              3.5                          19                  5289
#
#      Fandango_votes  Fandango_Difference  RottenTomatoes_diff
# 0             14846                  0.5                  -12
# 1             12640                  0.5                    5
# 2             12055                  0.5                  -10
# 3              1793                  0.5                  -66
# 4              1021                  0.5                  -14
# ..              ...                  ...                  ...
# 141            1348                  0.0                    9
# 142             192                  0.0                   15
# 143             118                  0.0                   19
# 144              59                  0.0                   19
# 145              41                  0.0                   24
#
# [146 rows x 23 columns]

# %%
all_sites['RottenTomatoes_diff'].abs().mean().round(2)
# Out:
# 15.1

# %%
sns.histplot(data=all_sites,x='RottenTomatoes_diff',kde=True)
# Out:
# <Axes: xlabel='RottenTomatoes_diff', ylabel='Count'>

# %%
# top 10 movies where critic rating higher than user would mean -ve values

all_sites.nsmallest(10,'RottenTomatoes_diff')
# Out:
#                           FILM  RottenTomatoes  RottenTomatoes_User  \
# 3       Do You Believe? (2015)              18                   84
# 85           Little Boy (2015)              20                   81
# 105    Hitman: Agent 47 (2015)               7                   49
# 134    The Longest Ride (2015)              31                   73
# 125  The Wedding Ringer (2015)              27                   66
# 132                 Max (2015)              35                   73
# 15              Taken 3 (2015)               9                   46
# 19               Pixels (2015)              17                   54
# 51            Entourage (2015)              32                   68
# 47                Annie (2014)              27                   61
#
#      Metacritic  Metacritic_User  IMDB  Fandango_Stars  Fandango_Ratingvalue  \
# 3            22              4.7   5.4             5.0                   4.5
# 85           30              5.9   7.4             4.5                   4.3
# 105          28              3.3   5.9             4.0                   3.9
# 134          33              4.8   7.2             4.5                   4.5
# 125          35              3.3   6.7             4.5                   4.4
# 132          47              5.9   7.0             4.5                   4.5
# 15           26              4.6   6.1             4.5                   4.1
# 19           27              5.3   5.6             4.5                   4.1
# 51           38              5.2   7.1             4.5                   4.2
# 47           33              4.8   5.2             4.5                   4.2
#
#      RT_norm  RT_user_norm  ...  RT_norm_round  RT_user_norm_round  \
# 3       0.90          4.20  ...            1.0                 4.0
# 85      1.00          4.05  ...            1.0                 4.0
# 105     0.35          2.45  ...            0.5                 2.5
# 134     1.55          3.65  ...            1.5                 3.5
# 125     1.35          3.30  ...            1.5                 3.5
# 132     1.75          3.65  ...            2.0                 3.5
# 15      0.45          2.30  ...            0.5                 2.5
# 19      0.85          2.70  ...            1.0                 2.5
# 51      1.60          3.40  ...            1.5                 3.5
# 47      1.35          3.05  ...            1.5                 3.0
#
#      Metacritic_norm_round  Metacritic_user_norm_round  IMDB_norm_round  \
# 3                      1.0                         2.5              2.5
# 85                     1.5                         3.0              3.5
# 105                    1.5                         1.5              3.0
# 134                    1.5                         2.5              3.5
# 125                    2.0                         1.5              3.5
# 132                    2.5                         3.0              3.5
# 15                     1.5                         2.5              3.0
# 19                     1.5                         2.5              3.0
# 51                     2.0                         2.5              3.5
# 47                     1.5                         2.5              2.5
#
#      Metacritic_user_vote_count  IMDB_user_vote_count  Fandango_votes  \
# 3                            31                  3136            1793
# 85                           38                  5927             811
# 105                          67                  4260             917
# 134                          49                 25214            2603
# 125                         126                 37292            6506
# 132                          15                  5444            3412
# 15                          240                104235            6757
# 19                          246                 19521            3886
# 51                           96                 21914            4279
# 47                          108                 19222            6835
#
#      Fandango_Difference  RottenTomatoes_diff
# 3                    0.5                  -66
# 85                   0.2                  -61
# 105                  0.1                  -42
# 134                  0.0                  -42
# 125                  0.1                  -39
# 132                  0.0                  -38
# 15                   0.4                  -37
# 19                   0.4                  -37
# 51                   0.3                  -36
# 47                   0.3                  -34
#
# [10 rows x 23 columns]

# %%
all_sites.nsmallest(10,'RottenTomatoes_diff')[['FILM','RottenTomatoes_diff']]
# Out:
#                           FILM  RottenTomatoes_diff
# 3       Do You Believe? (2015)                  -66
# 85           Little Boy (2015)                  -61
# 105    Hitman: Agent 47 (2015)                  -42
# 134    The Longest Ride (2015)                  -42
# 125  The Wedding Ringer (2015)                  -39
# 132                 Max (2015)                  -38
# 15              Taken 3 (2015)                  -37
# 19               Pixels (2015)                  -37
# 51            Entourage (2015)                  -36
# 47                Annie (2014)                  -34

# %%
# top 10 movies where user rating higher than critic would mean -ve values

all_sites.nlargest(10,'RottenTomatoes_diff')[['FILM','RottenTomatoes_diff']]
# Out:
#                                                 FILM  RottenTomatoes_diff
# 69                                 Mr. Turner (2014)                   42
# 112                                It Follows (2015)                   31
# 115                         While We're Young (2015)                   31
# 37                              Welcome to Me (2015)                   24
# 40                  I'll See You In My Dreams (2015)                   24
# 145               Kumiko, The Treasure Hunter (2015)                   24
# 90   The SpongeBob Movie: Sponge Out of Water (2015)                   23
# 7                                    Top Five (2014)                   22
# 11                                  Black Sea (2015)                   22
# 87                                     Maggie (2015)                   22

# %% [markdown]
# # MetaCritic

# %%
all_sites.columns
# Out:
# Index(['FILM', 'RottenTomatoes', 'RottenTomatoes_User', 'Metacritic',
#        'Metacritic_User', 'IMDB', 'Fandango_Stars', 'Fandango_Ratingvalue',
#        'RT_norm', 'RT_user_norm', 'Metacritic_norm', 'Metacritic_user_nom',
#        'IMDB_norm', 'RT_norm_round', 'RT_user_norm_round',
#        'Metacritic_norm_round', 'Metacritic_user_norm_round',
#        'IMDB_norm_round', 'Metacritic_user_vote_count', 'IMDB_user_vote_count',
#        'Fandango_votes', 'Fandango_Difference', 'RottenTomatoes_diff'],
#       dtype='object')

# %%
sns.scatterplot(data=all_sites,x='Metacritic',y='Metacritic_User')
# Out:
# <Axes: xlabel='Metacritic', ylabel='Metacritic_User'>

# %% [markdown]
# # IMDB

# %%
sns.scatterplot(data=all_sites,x='Metacritic_user_vote_count',y='IMDB_user_vote_count')
# Out:
# <Axes: xlabel='Metacritic_user_vote_count', ylabel='IMDB_user_vote_count'>

# %%
all_sites.nlargest(1,'IMDB_user_vote_count')
# Out:
#                          FILM  RottenTomatoes  RottenTomatoes_User  \
# 14  The Imitation Game (2014)              90                   92
#
#     Metacritic  Metacritic_User  IMDB  Fandango_Stars  Fandango_Ratingvalue  \
# 14          73              8.2   8.1             5.0                   4.6
#
#     RT_norm  RT_user_norm  ...  RT_norm_round  RT_user_norm_round  \
# 14      4.5           4.6  ...            4.5                 4.5
#
#     Metacritic_norm_round  Metacritic_user_norm_round  IMDB_norm_round  \
# 14                    3.5                         4.0              4.0
#
#     Metacritic_user_vote_count  IMDB_user_vote_count  Fandango_votes  \
# 14                         566                334164            8055
#
#     Fandango_Difference  RottenTomatoes_diff
# 14                  0.4                   -2
#
# [1 rows x 23 columns]

# %%
all_sites.nlargest(1,'Metacritic_user_vote_count')
# Out:
#                          FILM  RottenTomatoes  RottenTomatoes_User  \
# 88  Mad Max: Fury Road (2015)              97                   88
#
#     Metacritic  Metacritic_User  IMDB  Fandango_Stars  Fandango_Ratingvalue  \
# 88          89              8.7   8.3             4.5                   4.3
#
#     RT_norm  RT_user_norm  ...  RT_norm_round  RT_user_norm_round  \
# 88     4.85           4.4  ...            5.0                 4.5
#
#     Metacritic_norm_round  Metacritic_user_norm_round  IMDB_norm_round  \
# 88                    4.5                         4.5              4.0
#
#     Metacritic_user_vote_count  IMDB_user_vote_count  Fandango_votes  \
# 88                        2375                292023           10509
#
#     Fandango_Difference  RottenTomatoes_diff
# 88                  0.2                    9
#
# [1 rows x 23 columns]

# %% [markdown]
# ## Fandango vs All

# %%
df = pd.merge(fandango,all_sites,on='FILM',how='inner')

# %%
df
# Out:
#                                    FILM  STARS  RATING  VOTES  Year  \
# 0           Fifty Shades of Grey (2015)    4.0     3.9  34846  2015
# 1                 Jurassic World (2015)    4.5     4.5  34390  2015
# 2                American Sniper (2015)    5.0     4.8  34085  2015
# 3                      Furious 7 (2015)    5.0     4.8  33538  2015
# 4                     Inside Out (2015)    4.5     4.5  15749  2015
# ..                                  ...    ...     ...    ...   ...
# 140  Kumiko, The Treasure Hunter (2015)    3.5     3.5     41  2015
# 141  The Diary of a Teenage Girl (2015)    4.0     3.6     38  2015
# 142            The Wrecking Crew (2015)    4.5     4.2     38  2015
# 143                    Tangerine (2015)    4.0     3.9     36  2015
# 144            Maps to the Stars (2015)    3.5     3.1     35  2015
#
#      RottenTomatoes  RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  \
# 0                25                   42          46              3.2   4.2
# 1                71                   81          59              7.0   7.3
# 2                72                   85          72              6.6   7.4
# 3                81                   84          67              6.8   7.4
# 4                98                   90          94              8.9   8.6
# ..              ...                  ...         ...              ...   ...
# 140              87                   63          68              6.4   6.7
# 141              95                   81          87              6.3   7.0
# 142              93                   84          67              7.0   7.8
# 143              95                   86          86              7.3   7.4
# 144              60                   46          67              5.8   6.3
#
#      ...  RT_norm_round  RT_user_norm_round  Metacritic_norm_round  \
# 0    ...            1.5                 2.0                    2.5
# 1    ...            3.5                 4.0                    3.0
# 2    ...            3.5                 4.5                    3.5
# 3    ...            4.0                 4.0                    3.5
# 4    ...            5.0                 4.5                    4.5
# ..   ...            ...                 ...                    ...
# 140  ...            4.5                 3.0                    3.5
# 141  ...            5.0                 4.0                    4.5
# 142  ...            4.5                 4.0                    3.5
# 143  ...            5.0                 4.5                    4.5
# 144  ...            3.0                 2.5                    3.5
#
#      Metacritic_user_norm_round  IMDB_norm_round  Metacritic_user_vote_count  \
# 0                           1.5              2.0                         778
# 1                           3.5              3.5                        1281
# 2                           3.5              3.5                         850
# 3                           3.5              3.5                         764
# 4                           4.5              4.5                         807
# ..                          ...              ...                         ...
# 140                         3.0              3.5                          19
# 141                         3.0              3.5                          18
# 142                         3.5              4.0                           4
# 143                         3.5              3.5                          14
# 144                         3.0              3.0                          46
#
#      IMDB_user_vote_count  Fandango_votes  Fandango_Difference  \
# 0                  179506           34846                  0.1
# 1                  241807           34390                  0.0
# 2                  251856           34085                  0.2
# 3                  207211           33538                  0.2
# 4                   96252           15749                  0.0
# ..                    ...             ...                  ...
# 140                  5289              41                  0.0
# 141                  1107              38                  0.4
# 142                   732              38                  0.3
# 143                   696              36                  0.1
# 144                 22440              35                  0.4
#
#      RottenTomatoes_diff
# 0                    -17
# 1                    -10
# 2                    -13
# 3                     -3
# 4                      8
# ..                   ...
# 140                   24
# 141                   14
# 142                    9
# 143                    9
# 144                   14
#
# [145 rows x 27 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 145 entries, 0 to 144
# Data columns (total 27 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   FILM                        145 non-null    object
#  1   STARS                       145 non-null    float64
#  2   RATING                      145 non-null    float64
#  3   VOTES                       145 non-null    int64
#  4   Year                        145 non-null    object
#  5   RottenTomatoes              145 non-null    int64
#  6   RottenTomatoes_User         145 non-null    int64
#  7   Metacritic                  145 non-null    int64
#  8   Metacritic_User             145 non-null    float64
#  9   IMDB                        145 non-null    float64
#  10  Fandango_Stars              145 non-null    float64
#  11  Fandango_Ratingvalue        145 non-null    float64
#  12  RT_norm                     145 non-null    float64
#  13  RT_user_norm                145 non-null    float64
#  14  Metacritic_norm             145 non-null    float64
#  15  Metacritic_user_nom         145 non-null    float64
#  16  IMDB_norm                   145 non-null    float64
#  17  RT_norm_round               145 non-null    float64
#  18  RT_user_norm_round          145 non-null    float64
#  19  Metacritic_norm_round       145 non-null    float64
#  20  Metacritic_user_norm_round  145 non-null    float64
#  21  IMDB_norm_round             145 non-null    float64
#  22  Metacritic_user_vote_count  145 non-null    int64
#  23  IMDB_user_vote_count        145 non-null    int64
#  24  Fandango_votes              145 non-null    int64
#  25  Fandango_Difference         145 non-null    float64
#  26  RottenTomatoes_diff         145 non-null    int64
# dtypes: float64(17), int64(8), object(2)
# memory usage: 31.7+ KB

# %%
## NORMALIZATION

df['RT_N'] = np.round(df['RottenTomatoes']/20,1)
df['RTU_N'] = np.round(df['RottenTomatoes_User']/20,1)

# %%
## NORMALIZATION

df['META_N'] = np.round(df['Metacritic']/20,1)
df['METAU_N'] = np.round(df['Metacritic_User']/2,1)
df['IMDB_N'] = np.round(df['IMDB']/2,1)
df
# Out:
#                                    FILM  STARS  RATING  VOTES  Year  \
# 0           Fifty Shades of Grey (2015)    4.0     3.9  34846  2015
# 1                 Jurassic World (2015)    4.5     4.5  34390  2015
# 2                American Sniper (2015)    5.0     4.8  34085  2015
# 3                      Furious 7 (2015)    5.0     4.8  33538  2015
# 4                     Inside Out (2015)    4.5     4.5  15749  2015
# ..                                  ...    ...     ...    ...   ...
# 140  Kumiko, The Treasure Hunter (2015)    3.5     3.5     41  2015
# 141  The Diary of a Teenage Girl (2015)    4.0     3.6     38  2015
# 142            The Wrecking Crew (2015)    4.5     4.2     38  2015
# 143                    Tangerine (2015)    4.0     3.9     36  2015
# 144            Maps to the Stars (2015)    3.5     3.1     35  2015
#
#      RottenTomatoes  RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  \
# 0                25                   42          46              3.2   4.2
# 1                71                   81          59              7.0   7.3
# 2                72                   85          72              6.6   7.4
# 3                81                   84          67              6.8   7.4
# 4                98                   90          94              8.9   8.6
# ..              ...                  ...         ...              ...   ...
# 140              87                   63          68              6.4   6.7
# 141              95                   81          87              6.3   7.0
# 142              93                   84          67              7.0   7.8
# 143              95                   86          86              7.3   7.4
# 144              60                   46          67              5.8   6.3
#
#      ...  Metacritic_user_vote_count  IMDB_user_vote_count  Fandango_votes  \
# 0    ...                         778                179506           34846
# 1    ...                        1281                241807           34390
# 2    ...                         850                251856           34085
# 3    ...                         764                207211           33538
# 4    ...                         807                 96252           15749
# ..   ...                         ...                   ...             ...
# 140  ...                          19                  5289              41
# 141  ...                          18                  1107              38
# 142  ...                           4                   732              38
# 143  ...                          14                   696              36
# 144  ...                          46                 22440              35
#
#      Fandango_Difference  RottenTomatoes_diff  RT_N  RTU_N  META_N  METAU_N  \
# 0                    0.1                  -17   1.2    2.1     2.3      1.6
# 1                    0.0                  -10   3.6    4.0     3.0      3.5
# 2                    0.2                  -13   3.6    4.2     3.6      3.3
# 3                    0.2                   -3   4.0    4.2     3.4      3.4
# 4                    0.0                    8   4.9    4.5     4.7      4.4
# ..                   ...                  ...   ...    ...     ...      ...
# 140                  0.0                   24   4.4    3.2     3.4      3.2
# 141                  0.4                   14   4.8    4.0     4.4      3.2
# 142                  0.3                    9   4.6    4.2     3.4      3.5
# 143                  0.1                    9   4.8    4.3     4.3      3.6
# 144                  0.4                   14   3.0    2.3     3.4      2.9
#
#      IMDB_N
# 0       2.1
# 1       3.6
# 2       3.7
# 3       3.7
# 4       4.3
# ..      ...
# 140     3.4
# 141     3.5
# 142     3.9
# 143     3.7
# 144     3.2
#
# [145 rows x 32 columns]

# %%
df.columns
# Out:
# Index(['FILM', 'STARS', 'RATING', 'VOTES', 'Year', 'RottenTomatoes',
#        'RottenTomatoes_User', 'Metacritic', 'Metacritic_User', 'IMDB',
#        'Fandango_Stars', 'Fandango_Ratingvalue', 'RT_norm', 'RT_user_norm',
#        'Metacritic_norm', 'Metacritic_user_nom', 'IMDB_norm', 'RT_norm_round',
#        'RT_user_norm_round', 'Metacritic_norm_round',
#        'Metacritic_user_norm_round', 'IMDB_norm_round',
#        'Metacritic_user_vote_count', 'IMDB_user_vote_count', 'Fandango_votes',
#        'Fandango_Difference', 'RottenTomatoes_diff', 'RT_N', 'RTU_N', 'META_N',
#        'METAU_N', 'IMDB_N'],
#       dtype='object')

# %%
df_N = df[['STARS','RATING','RT_N','RTU_N','META_N','METAU_N','IMDB_N']]
df_N
# Out:
#      STARS  RATING  RT_N  RTU_N  META_N  METAU_N  IMDB_N
# 0      4.0     3.9   1.2    2.1     2.3      1.6     2.1
# 1      4.5     4.5   3.6    4.0     3.0      3.5     3.6
# 2      5.0     4.8   3.6    4.2     3.6      3.3     3.7
# 3      5.0     4.8   4.0    4.2     3.4      3.4     3.7
# 4      4.5     4.5   4.9    4.5     4.7      4.4     4.3
# ..     ...     ...   ...    ...     ...      ...     ...
# 140    3.5     3.5   4.4    3.2     3.4      3.2     3.4
# 141    4.0     3.6   4.8    4.0     4.4      3.2     3.5
# 142    4.5     4.2   4.6    4.2     3.4      3.5     3.9
# 143    4.0     3.9   4.8    4.3     4.3      3.6     3.7
# 144    3.5     3.1   3.0    2.3     3.4      2.9     3.2
#
# [145 rows x 7 columns]

# %%
plt.figure(figsize=(10,4))
sns.kdeplot(data=df_N,x='RATING',fill= True, label='True RATINGS')
sns.kdeplot(data=df_N,x='STARS',fill= True, label='STARS')
sns.kdeplot(data=df_N,x='RT_N',fill= True, label='RT_N')
sns.kdeplot(data=df_N,x='RTU_N',fill= True, label='RTU_N')
sns.kdeplot(data=df_N,x='META_N',fill= True, label='META_N')
sns.kdeplot(data=df_N,x='METAU_N',fill= True, label='METAU_N')
sns.kdeplot(data=df_N,x='IMDB_N',fill= True, label='IMDB_N')
plt.title('Fandango vs All')
plt.legend(loc=(1.02,0.5))
plt.show()

# %%
plt.figure(figsize=(10,4))
sns.kdeplot(data=df_N,x='STARS',fill= True, label='STARS')
sns.kdeplot(data=df_N,x='RT_N',fill= True, label='RT_N')
plt.legend(loc=(1.02,0.5))
plt.show()

# %%
plt.figure(figsize=(10,4))
sns.histplot(df_N)
# Out:
# <Axes: ylabel='Count'>

# %%
df_N_F = df[['FILM','STARS','RATING','RT_N','RTU_N','META_N','METAU_N','IMDB_N']]
df_N_F
# Out:
#                                    FILM  STARS  RATING  RT_N  RTU_N  META_N  \
# 0           Fifty Shades of Grey (2015)    4.0     3.9   1.2    2.1     2.3
# 1                 Jurassic World (2015)    4.5     4.5   3.6    4.0     3.0
# 2                American Sniper (2015)    5.0     4.8   3.6    4.2     3.6
# 3                      Furious 7 (2015)    5.0     4.8   4.0    4.2     3.4
# 4                     Inside Out (2015)    4.5     4.5   4.9    4.5     4.7
# ..                                  ...    ...     ...   ...    ...     ...
# 140  Kumiko, The Treasure Hunter (2015)    3.5     3.5   4.4    3.2     3.4
# 141  The Diary of a Teenage Girl (2015)    4.0     3.6   4.8    4.0     4.4
# 142            The Wrecking Crew (2015)    4.5     4.2   4.6    4.2     3.4
# 143                    Tangerine (2015)    4.0     3.9   4.8    4.3     4.3
# 144            Maps to the Stars (2015)    3.5     3.1   3.0    2.3     3.4
#
#      METAU_N  IMDB_N
# 0        1.6     2.1
# 1        3.5     3.6
# 2        3.3     3.7
# 3        3.4     3.7
# 4        4.4     4.3
# ..       ...     ...
# 140      3.2     3.4
# 141      3.2     3.5
# 142      3.5     3.9
# 143      3.6     3.7
# 144      2.9     3.2
#
# [145 rows x 8 columns]

# %%
df_N_F = df[['FILM','STARS','RATING','RT_N','RTU_N','META_N','METAU_N','IMDB_N']]
df_N_F['N_diff_RT_S'] = df['STARS']
df_N_F
# Out:
# C:\Users\Ruchi Garg\AppData\Local\Temp\ipykernel_25188\3404688762.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_N_F['N_diff_RT_S'] = df['STARS']
#                                    FILM  STARS  RATING  RT_N  RTU_N  META_N  \
# 0           Fifty Shades of Grey (2015)    4.0     3.9   1.2    2.1     2.3
# 1                 Jurassic World (2015)    4.5     4.5   3.6    4.0     3.0
# 2                American Sniper (2015)    5.0     4.8   3.6    4.2     3.6
# 3                      Furious 7 (2015)    5.0     4.8   4.0    4.2     3.4
# 4                     Inside Out (2015)    4.5     4.5   4.9    4.5     4.7
# ..                                  ...    ...     ...   ...    ...     ...
# 140  Kumiko, The Treasure Hunter (2015)    3.5     3.5   4.4    3.2     3.4
# 141  The Diary of a Teenage Girl (2015)    4.0     3.6   4.8    4.0     4.4
# 142            The Wrecking Crew (2015)    4.5     4.2   4.6    4.2     3.4
# 143                    Tangerine (2015)    4.0     3.9   4.8    4.3     4.3
# 144            Maps to the Stars (2015)    3.5     3.1   3.0    2.3     3.4
#
#      METAU_N  IMDB_N  N_diff_RT_S
# 0        1.6     2.1          4.0
# 1        3.5     3.6          4.5
# 2        3.3     3.7          5.0
# 3        3.4     3.7          5.0
# 4        4.4     4.3          4.5
# ..       ...     ...          ...
# 140      3.2     3.4          3.5
# 141      3.2     3.5          4.0
# 142      3.5     3.9          4.5
# 143      3.6     3.7          4.0
# 144      2.9     3.2          3.5
#
# [145 rows x 9 columns]

# %%
df_N_F_10 = df_N_F.nsmallest(10,'RT_N')

# %%
df_N_F_10
# Out:
#                              FILM  STARS  RATING  RT_N  RTU_N  META_N  \
# 49  Paul Blart: Mall Cop 2 (2015)    3.5     3.5   0.2    1.8     0.6
# 25                 Taken 3 (2015)    4.5     4.1   0.4    2.3     1.3
# 28          Fantastic Four (2015)    3.0     2.7   0.4    1.0     1.4
# 54             Hot Pursuit (2015)    4.0     3.7   0.4    1.8     1.6
# 84        Hitman: Agent 47 (2015)    4.0     3.9   0.4    2.4     1.4
# 50       The Boy Next Door (2015)    4.0     3.6   0.5    1.8     1.5
# 77             Seventh Son (2015)    3.5     3.2   0.6    1.8     1.5
# 78               Mortdecai (2015)    3.5     3.2   0.6    1.5     1.4
# 83              Sinister 2 (2015)    3.5     3.3   0.6    1.7     1.6
# 87     Unfinished Business (2015)    3.5     3.2   0.6    1.4     1.6
#
#     METAU_N  IMDB_N
# 49      1.2     2.2
# 25      2.3     3.0
# 28      1.2     2.0
# 54      1.8     2.4
# 84      1.6     3.0
# 50      2.8     2.3
# 77      2.0     2.8
# 78      1.6     2.8
# 83      2.5     2.8
# 87      1.9     2.7

# %%
plt.figure(figsize=(10,4))
sns.kdeplot(data=df_N_F_10,x='RT_N',fill= True, label='RT_N')
sns.kdeplot(data=df_N_F_10,x='STARS',fill= True, label='STARS')
sns.kdeplot(data=df_N_F_10,x='RTU_N',fill= True, label='RTU_N')
sns.kdeplot(data=df_N_F_10,x='META_N',fill= True, label='META_N')
sns.kdeplot(data=df_N_F_10,x='IMDB_N',fill= True, label='IMDB_N')
sns.kdeplot(data=df_N_F_10,x='RATING',fill= True, label='RATING')
plt.legend(loc=(1.02,0.5))
plt.show()

# %% [markdown]
# # Inferences:
#
# ### 1. In KDE plot, we can see that fandango has most uneven distribution
